# %%
#import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Data_file.csv')

# %%
df.head()
# Out:
#     Student ID  Age  Gender  Academic Performance (GPA)  Study Hours Per Week  \
# 0  802-17-3671   22  Female                           2                     9
# 1  871-12-8572   25  Female                           0                    28
# 2  495-13-2672   24  Female                           0                    45
# 3  365-77-2496   20    Male                           2                     8
# 4  664-76-5622   28    Male                           0                    14
#
#    Social Media Usage (Hours per day)  Sleep Duration (Hours per night)  \
# 0                                   2                                12
# 1                                   0                                 6
# 2                                   3                                12
# 3                                   7                                 7
# 4                                   6                                 8
#
# ...

# %%
df.describe()
# Out:
#               Age  Academic Performance (GPA)  Study Hours Per Week  \
# count  760.000000                  760.000000            760.000000
# mean    23.919737                    1.996053             29.130263
# std      3.819392                    1.416535             18.104662
# min     18.000000                    0.000000              0.000000
# 25%     21.000000                    1.000000             13.000000
# 50%     24.000000                    2.000000             29.000000
# 75%     27.000000                    3.000000             45.000000
# max     30.000000                    4.000000             60.000000
#
#        Social Media Usage (Hours per day)  Sleep Duration (Hours per night)  \
# count                          760.000000                        760.000000
# mean                             4.234211                          8.093421
# std                              2.565174                          2.596838
# ...

# %%
df.columns
# Out:
# Index(['Student ID', 'Age', 'Gender', 'Academic Performance (GPA)',
#        'Study Hours Per Week', 'Social Media Usage (Hours per day)',
#        'Sleep Duration (Hours per night)',
#        'Physical Exercise (Hours per week)', 'Family Support  ',
#        'Financial Stress', 'Peer Pressure', 'Relationship Stress',
#        'Mental Stress Level', 'Counseling Attendance', 'Diet Quality',
#        'Stress Coping Mechanisms', 'Cognitive Distortions',
#        'Family Mental Health History', 'Medical Condition', 'Substance Use'],
#       dtype='object')

# %% [markdown]
# <h1>EDA</h1>

# %%
df.isnull().sum()
# Out:
# Student ID                            0
# Age                                   0
# Gender                                0
# Academic Performance (GPA)            0
# Study Hours Per Week                  0
# Social Media Usage (Hours per day)    0
# Sleep Duration (Hours per night)      0
# Physical Exercise (Hours per week)    0
# Family Support                        0
# Financial Stress                      0
# Peer Pressure                         0
# Relationship Stress                   0
# Mental Stress Level                   0
# Counseling Attendance                 0
# Diet Quality                          0
# Stress Coping Mechanisms              0
# Cognitive Distortions                 0
# Family Mental Health History          0
# Medical Condition                     0
# Substance Use                         0
# dtype: int64

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)
# Out:
#                                          Age  Academic Performance (GPA)  \
# Age                                 1.000000                    0.001159
# Academic Performance (GPA)          0.001159                    1.000000
# Study Hours Per Week                0.023549                   -0.000237
# Social Media Usage (Hours per day) -0.002382                    0.033613
# Sleep Duration (Hours per night)    0.036756                   -0.017450
# Physical Exercise (Hours per week) -0.032789                    0.035845
# Family Support                     -0.003340                    0.001262
# Financial Stress                   -0.004682                    0.050622
# Peer Pressure                       0.059751                    0.018018
# Relationship Stress                -0.005101                    0.014869
# Mental Stress Level                -0.048228                   -0.036178
# Diet Quality                       -0.004613                   -0.016561
# ...

# %%
# import sweetviz

# my_report=sweetviz.analyze(df,target_feat='Academic Performance (GPA)')
# my_report.show_html('my_report1.html')

# %% [markdown]
# <h2>Droping the ID column</h2>

# %%
df=df.drop('Student ID',axis=1)

# %%
df.head()
# Out:
#    Age  Gender  Academic Performance (GPA)  Study Hours Per Week  \
# 0   22  Female                           2                     9
# 1   25  Female                           0                    28
# 2   24  Female                           0                    45
# 3   20    Male                           2                     8
# 4   28    Male                           0                    14
#
#    Social Media Usage (Hours per day)  Sleep Duration (Hours per night)  \
# 0                                   2                                12
# 1                                   0                                 6
# 2                                   3                                12
# 3                                   7                                 7
# 4                                   6                                 8
#
#    Physical Exercise (Hours per week)  Family Support    Financial Stress  \
# ...

# %%
df['Stress Coping Mechanisms'].unique()
# Out:
# array(['Walking or Nature Walks', 'Meditation', 'Reading',
#        'Social Media Engagement', 'Exercise', 'Talking to Friends',
#        'Yoga', 'Watching Sports', 'Spending Time Alone', 'Travelling'],
#       dtype=object)

# %% [markdown]
# <h2>Categorical variables</h2>

# %%
# df=pd.get_dummies(df,columns=['Gender','Counseling Attendance','Family Mental Health History','Medical Condition'],drop_first=True)

# %%
# df.head()

# %%
plt.scatter(data['Study Hours Per Week'], data['Academic Performance (GPA)'])
plt.show()
